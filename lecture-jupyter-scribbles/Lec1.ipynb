# %% [markdown]
# # This is the first lecture
#
# $$
# x+y = 3
# $$

# %%
import numpy as np
from numpy.random import rand, seed

# %%
rand() # a random number, not with an initilized seed....
# Out:
# 0.25092544554771945

# %%
seed(2026)
rand(), rand(), rand()
# Out:
# (0.21934563492692294, 0.4130117368786672, 0.9766354781603012)

# %%
seed(2025)
rand(), rand(), rand()
# Out:
# (0.1354881636779618, 0.887851702730378, 0.9326056398865025)
